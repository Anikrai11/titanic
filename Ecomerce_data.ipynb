# %% [markdown]
# <a href="https://colab.research.google.com/github/Anikrai11/titanic/blob/main/Ecomerce_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("/content/new module aa.csv")

# %%
df
# Out:
#       prefix    first       last              email  gender  age  \
# 0        Dr.      Ray     Morton    sebvajom@kol.km    Male   38
# 1       Miss  Claudia  Rodriquez      acu@jatsot.ug  Female   51
# 2       Miss    Harry      Meyer          zuz@lo.wf  Female   51
# 3       Miss    Edith    Gilbert  hansohsi@jupec.md  Female   55
# 4        Dr.     Lura     Murphy     webediti@je.st  Female   20
# ...      ...      ...        ...                ...     ...  ...
# 29995    Mr.     John    Maxwell  larlisu@sejenu.ad  Female   38
# 29996    Dr.   Alfred       Bass      le@duridzo.gh  Female   24
# 29997   Mrs.   Edward     Curtis      ta@kucemah.et  Female   56
# 29998    Mr.      Max      Woods       li@mincoz.mp  Female   64
# 29999    Mr.     Olga  Rodriguez         ner@ota.ec    Male   22
#
#                              company                profession  \
# 0                     Medtronic Inc.          Health Therapist
# ...

# %%
df.head()
# Out:
#   prefix    first       last              email  gender  age  \
# 0    Dr.      Ray     Morton    sebvajom@kol.km    Male   38
# 1   Miss  Claudia  Rodriquez      acu@jatsot.ug  Female   51
# 2   Miss    Harry      Meyer          zuz@lo.wf  Female   51
# 3   Miss    Edith    Gilbert  hansohsi@jupec.md  Female   55
# 4    Dr.     Lura     Murphy     webediti@je.st  Female   20
#
#                         company              profession           phone  \
# 0                Medtronic Inc.        Health Therapist  (987) 619-2695
# 1  Ames Department Stores, Inc.        Health Therapist  (356) 736-7352
# 2                     CSX Corp.     Political Scientist  (539) 246-1806
# 3        Murphy Oil Corporation  Transportation Manager  (984) 962-7494
# 4                  PETsMART Inc            Statistician  (902) 568-9748
#
#     postal province         cc_no  cc_exp                    cc_type  \
# 0  B6V 3W3       MB  5.020000e+15  18-May                       Solo
# ...

# %%
df.shape
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 20 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   prefix      30000 non-null  object
#  1   first       30000 non-null  object
#  2   last        30000 non-null  object
#  3   email       30000 non-null  object
#  4   gender      30000 non-null  object
#  5   age         30000 non-null  int64
#  6   company     30000 non-null  object
#  7   profession  30000 non-null  object
#  8   phone       30000 non-null  object
#  9   postal      30000 non-null  object
#  10  province    30000 non-null  object
#  11  cc_no       30000 non-null  float64
#  12  cc_exp      30000 non-null  object
#  13  cc_type     30000 non-null  object
#  14  price(CAD)  30000 non-null  float64
#  15  fav_color   30000 non-null  object
#  16  ip          30000 non-null  object
#  17  weekday     30000 non-null  object
#  18  ampm        30000 non-null  object
# ...

# %% [markdown]
# # 4

# %%
print(df["age"].min())
print(df["age"].max())
print(df["age"].mean())
# Out:
# 18
# 65
# 41.550066666666666

# %% [markdown]
# # 5

# %%
df["first"].value_counts().head(3)
# Out:
# first
# Willie     130
# Francis    124
# Eula        86
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['prefix', 'first', 'last', 'email', 'gender', 'age', 'company',
#        'profession', 'phone', 'postal', 'province', 'cc_no', 'cc_exp',
#        'cc_type', 'price(CAD)', 'fav_color', 'ip', 'weekday', 'ampm', 'date'],
#       dtype='object')

# %% [markdown]
# # 6

# %%
phone_count=(df["phone"].value_counts())
dupliactes=phone_count[phone_count==2]
print(dupliactes)
phone_number=dupliactes.index[0]
print(df[df["phone"]==phone_number][["first","last","email","phone"]])
# Out:
# phone
# (263) 382-8004    2
# Name: count, dtype: int64
#     first   last                email           phone
# 15  Lilly  Tyler      kofadu@itohi.tf  (263) 382-8004
# 16  Peter   Cain  megkosig@anazeor.gn  (263) 382-8004

# %% [markdown]
# # 7

# %%
print((df['profession']=="Structural Engineer").sum())
# Out:
# 87

# %%
df.columns
# Out:
# Index(['prefix', 'first', 'last', 'email', 'gender', 'age', 'company',
#        'profession', 'phone', 'postal', 'province', 'cc_no', 'cc_exp',
#        'cc_type', 'price(CAD)', 'fav_color', 'ip', 'weekday', 'ampm', 'date'],
#       dtype='object')

# %% [markdown]
# # 8

# %%
result=df[(df['profession']=="Structural Engineer")&(df["gender"]=="Male")]
print(len(result))
# Out:
# 43

# %% [markdown]
# # 9

# %%
reasult=df[(df["profession"]=="Structural Engineer")&(df["gender"]=="Female")&(df["province"]=="AB")]

# %%
print(reasult[["first","last","gender","profession","province"]])
# Out:
#       first      last  gender           profession province
# 8858    Roy   Stanley  Female  Structural Engineer       AB
# 9058   Lora   Kennedy  Female  Structural Engineer       AB
# 24736  Nell  Richards  Female  Structural Engineer       AB
# 29865   Don  McDaniel  Female  Structural Engineer       AB

# %%
df.columns
# Out:
# Index(['prefix', 'first', 'last', 'email', 'gender', 'age', 'company',
#        'profession', 'phone', 'postal', 'province', 'cc_no', 'cc_exp',
#        'cc_type', 'price(CAD)', 'fav_color', 'ip', 'weekday', 'ampm', 'date'],
#       dtype='object')

# %% [markdown]
# # 10

# %%
print(df["price(CAD)"].max())
print(df["price(CAD)"].min())
print(df["price(CAD)"].mean())
# Out:
# 100.0
# 0.0
# 49.990775

# %% [markdown]
# # 11

# %%
cast=df[df["price(CAD)"]==0]
print(cast[["first","last","email","price(CAD)"]])
# Out:
#        first   last           email  price(CAD)
# 5320   Bruce  Bryan  ru@pubuspuh.cl         0.0
# 10597  Flora  Clark      wad@me.com         0.0

# %% [markdown]
# # New Section

# %% [markdown]
# # 12

# %%
cast=df[df["price(CAD)"]>=100]
print(len(cast))
print(cast[["first","last","email","price(CAD)"]])
# Out:
# 3
#          first         last          email  price(CAD)
# 76     Gregory        Brown     hav@jek.gs       100.0
# 21093     Cody  Christensen    get@jovu.ag       100.0
# 24385   Lizzie        Dixon  goh@tuwjaz.gd       100.0

# %%
df.columns
# Out:
# Index(['prefix', 'first', 'last', 'email', 'gender', 'age', 'company',
#        'profession', 'phone', 'postal', 'province', 'cc_no', 'cc_exp',
#        'cc_type', 'price(CAD)', 'fav_color', 'ip', 'weekday', 'ampm', 'date'],
#       dtype='object')

# %%
df["cc_no"]
# Out:
# 0        5.020000e+15
# 1        5.020000e+15
# 2        6.300000e+15
# 3        3.530000e+15
# 4        4.030000e+15
#              ...
# 29995    6.330000e+15
# 29996    2.010000e+14
# 29997    2.010000e+14
# 29998    3.000000e+13
# 29999    6.300000e+15
# Name: cc_no, Length: 30000, dtype: float64

# %% [markdown]
# ## problem face this question

# %% [markdown]
# # 13 number is very defficult

# %%
df["cc_no"]
# Out:
# 0        5.020000e+15
# 1        5.020000e+15
# 2        6.300000e+15
# 3        3.530000e+15
# 4        4.030000e+15
#              ...
# 29995    6.330000e+15
# 29996    2.010000e+14
# 29997    2.010000e+14
# 29998    3.000000e+13
# 29999    6.300000e+15
# Name: cc_no, Length: 30000, dtype: float64

# %%
ttt=df[df["cc_no"]==5020000000000230]
print(len(ttt))
# Out:
# 0

# %%
df["cc_exp"]
# Out:
# 0        18-May
# 1        28-Jul
# 2        23-Feb
# 3        28-Feb
# 4        25-Oct
#           ...
# 29995    28-Apr
# 29996    26-Dec
# 29997    21-Jun
# 29998    23-Aug
# 29999    24-May
# Name: cc_exp, Length: 30000, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 20 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   prefix      30000 non-null  object
#  1   first       30000 non-null  object
#  2   last        30000 non-null  object
#  3   email       30000 non-null  object
#  4   gender      30000 non-null  object
#  5   age         30000 non-null  int64
#  6   company     30000 non-null  object
#  7   profession  30000 non-null  object
#  8   phone       30000 non-null  object
#  9   postal      30000 non-null  object
#  10  province    30000 non-null  object
#  11  cc_no       30000 non-null  float64
#  12  cc_exp      30000 non-null  object
#  13  cc_type     30000 non-null  object
#  14  price(CAD)  30000 non-null  float64
#  15  fav_color   30000 non-null  object
#  16  ip          30000 non-null  object
#  17  weekday     30000 non-null  object
#  18  ampm        30000 non-null  object
# ...

# %% [markdown]
# # 14

# %%
f=pd.to_datetime(df["cc_exp"],format="%y-%b")

# %%
cards_2019=df[f.dt.year==2019]
print(len(cards_2019))
# Out:
# 2684

# %%
e=df[df["cc_type"]=="Visa"].value_counts()
e
# Out:
# prefix  first      last       email                 gender  age  company                       profession                          phone           postal   province  cc_no         cc_exp  cc_type  price(CAD)  fav_color  ip               weekday    ampm  date
# Mrs.    Zachary    Flores     vovuh@zeli.uy         Male    62   Lowe's Companies Inc.         Membership Chairman                 (777) 396-1076  V6R 4X4  ON        6.330000e+15  28-Feb  Visa     59.09       Yellow     25.125.152.53    Saturday   am    10/2/2006     1
# Dr.     Adam       Brooks     jasun@gmail.com       Male    42   Payless Shoesource Inc        Organizational Development Manager  (947) 945-1387  C5G 3P4  NS        4.760000e+15  22-Jun  Visa     38.10       White      245.1.199.5      Thursday   pm    12/18/2035    1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 20 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   prefix      30000 non-null  object
#  1   first       30000 non-null  object
#  2   last        30000 non-null  object
#  3   email       30000 non-null  object
#  4   gender      30000 non-null  object
#  5   age         30000 non-null  int64
#  6   company     30000 non-null  object
#  7   profession  30000 non-null  object
#  8   phone       30000 non-null  object
#  9   postal      30000 non-null  object
#  10  province    30000 non-null  object
#  11  cc_no       30000 non-null  float64
#  12  cc_exp      30000 non-null  object
#  13  cc_type     30000 non-null  object
#  14  price(CAD)  30000 non-null  float64
#  15  fav_color   30000 non-null  object
#  16  ip          30000 non-null  object
#  17  weekday     30000 non-null  object
#  18  ampm        30000 non-null  object
# ...

# %% [markdown]
# # 15

# %%
print((df["cc_type"]=="Visa").sum())
# Out:
# 1721

# %%
df["price(CAD)"]
# Out:
# 0         8.36
# 1        68.31
# 2        34.65
# 3        64.59
# 4        20.83
#          ...
# 29995    90.37
# 29996     5.94
# 29997    65.66
# 29998    52.66
# 29999    17.71
# Name: price(CAD), Length: 30000, dtype: float64

# %% [markdown]
# # 16

# %%
result=df[(df["price(CAD)"]==100)&(df["cc_type"]=="Visa")]

# %%
r=(result[["first","last","cc_type","price(CAD)"]])
r
# Out:
#       first   last cc_type  price(CAD)
# 76  Gregory  Brown    Visa       100.0

# %% [markdown]
# #17

# %%
df["profession"].value_counts().head(2)
# Out:
# profession
# Preschool Teacher       112
# Distribution Manager    107
# Name: count, dtype: int64

# %% [markdown]
# # 18

# %%
providers=df["email"].str.split("@").str[1]
p=(providers.value_counts().head(5))
p
# Out:
# email
# gmail.com      1687
# me.com         1676
# outlook.com    1664
# live.com       1660
# hotmail.com    1659
# Name: count, dtype: int64

# %% [markdown]
# # 19

# %%
edu=(df["email"].str.split("@").str[1]=="am.edu")
e=edu.sum()
e
# Out:
# np.int64(1)

# %% [markdown]
# # 20

# %%
w=df["weekday"].value_counts()
w
# Out:
# weekday
# Saturday     4376
# Wednesday    4365
# Thursday     4327
# Friday       4316
# Monday       4216
# Sunday       4213
# Tuesday      4187
# Name: count, dtype: int64
